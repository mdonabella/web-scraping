# %%
##this method scrapes around 100 tweets at time using an API key from ScraperAPI. To my understanding, using the free version of this site, you can obtain a limited amount of "API credits" each month. 
##there are other ways to work with ScraperAPI, but this (code below) is the most user-friendly I've found
##There are limitations to the method, the biggest being that you do not receive the entirety of each tweet. Depending on your goal, this could be a problem.
##First, obtain temporary credentials through ScraperAPI: https://www.scraperapi.com/
##Once you have API credentials, you should be able to follow code below, but see different variation here: https://www.scraperapi.com/blog/scrape-twitter-data/

# %%
pip install snscrape
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

# %%
twitter_data = []

# %%
payload = {
    'api_key':'cf8ed4eee03eed33f48ce2c7acd6b319', ##insert your own key here
    'query':'assistive technology', ##insert desired keyword here
    'num':'100'
}
response = requests.get(
    'https://api.scraperapi.com/structured/twitter/search',params=payload
)
data = response.json()

# %%
##this will print data in json format. While you can most certainly manipulate the code to save data as csv, I just use an online converter: https://www.convertcsv.com/json-to-csv.htm

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "assistive technology"',
#   'total_results': 11700,
#   'time_taken_displayed': 0.45},
#  'organic_results': [{'position': 0,
#    'title': 'Disability Rights California',
#    'snippet': 'The term “assistive technology” means the technology used in an assistive technology device or assistive technology service for increasing,\xa0...',
#    'highlighs': ['assistive technology',
#     'assistive technology',
#     'assistive technology'],
#    'link': 'https://twitter.com/DisabilityCA/status/1730645955870158940',
#    'displayed_link': 'https://twitter.com › DisabilityCA › status'},
#   {'position': 1,
#    'title': 'Assistive Technology (@MITAssistivTech) / X',
#    'snippet': 'We are an assistive technology group. We receive requests from people with a disability, design and build customized devices that meet their needs.',
#    'highlighs': ['assistive technology'],
#    'link': 'https://twitter.com/MITAssistivTech',
# ...
